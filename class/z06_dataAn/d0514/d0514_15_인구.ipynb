# %%
import pandas as pd
import numpy as np

df_1 = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,nrows=1,thousands=',',index_col='행정기관',usecols='B,E:Y')
# df_m.info()  # 값들이 모두 str이었음
df_2 = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,nrows=1,thousands=',',index_col='행정기관',usecols='B,AX:BS')
df_3 = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,nrows=1,thousands=',',index_col='행정기관',usecols='B,CS:DM')
df_4 = pd.read_excel('../z20_data/20230104_연령별인구현황2.xlsx',skiprows=3,nrows=1,thousands=',',index_col='행정기관',usecols='B,EM:FG')

df_1
# Out:
#         0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세   35~39세  \
# 행정기관
# 전국    726460  1072653  1211077  1211949  1524378  1823908  1737714  1684266
#
#        40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  75~79세  \
# 행정기관                    ...
# 전국    2055130  2039606  ...  2052227  2097254  1554976  1038388  713448
#
#       80~84세  85~89세  90~94세  95~99세  100세 이상
# 행정기관
# 전국    507915  212726   54180    8880     1307
#
# [1 rows x 21 columns]

# %%
df_1['0~14세'] = df_1['0~4세'] + df_1['5~9세'] +df_1['10~14세']
df_1['15~64세'] = df_1['15~19세'] + df_1['20~24세'] + df_1['25~29세'] + df_1['30~34세'] + df_1['35~39세'] + df_1['40~44세']\
    + df_1['45~49세'] + df_1['50~54세'] + df_1['55~59세'] + df_1['60~64세']
df_1['65세 이상'] = df_1['65~69세'] + df_1['65~69세'] + df_1['70~74세'] + df_1['75~79세'] + df_1['80~84세']\
    + df_1['85~89세'] + df_1['90~94세'] + df_1['95~99세'] + df_1['100세 이상']
#------------------------------------------------------------------------------------
df_2['0~14세'] = df_2['0~4세.2'] + df_2['5~9세.2'] +df_2['10~14세.2']
df_2['15~64세'] = df_2['15~19세.2'] + df_2['20~24세.2'] + df_2['25~29세.2'] + df_2['30~34세.2'] + df_2['35~39세.2'] + df_2['40~44세.2']\
    + df_2['45~49세.2'] + df_2['50~54세.2'] + df_2['55~59세.2'] + df_2['60~64세.2']
df_2['65세 이상'] = df_2['65~69세.2'] + df_2['65~69세.2'] + df_2['70~74세.2'] + df_2['75~79세.2'] + df_2['80~84세.2']\
    + df_2['85~89세.2'] + df_2['90~94세.2'] + df_2['95~99세.2'] + df_2['100세 이상.2']
#-----------------------------------------------------------------------------------  
df_3['0~14세'] = df_3['0~4세.4'] + df_3['5~9세.4'] +df_3['10~14세.4']
df_3['15~64세'] = df_3['15~19세.4'] + df_3['20~24세.4'] + df_3['25~29세.4'] + df_3['30~34세.4'] + df_3['35~39세.4'] + df_3['40~44세.4']\
    + df_3['45~49세.4'] + df_3['50~54세.4'] + df_3['55~59세.4'] + df_3['60~64세.4']
df_3['65세 이상'] = df_3['65~69세.4'] + df_3['65~69세.4'] + df_3['70~74세.4'] + df_3['75~79세.4'] + df_3['80~84세.4']\
    + df_3['85~89세.4'] + df_3['90~94세.4'] + df_3['95~99세.4'] + df_3['100세 이상.4']
#----------------------------------------------------------------------------------------
df_4['0~14세'] = df_4['0~4세.6'] + df_4['5~9세.6'] +df_4['10~14세.6']
df_4['15~64세'] = df_4['15~19세.6'] + df_4['20~24세.6'] + df_4['25~29세.6'] + df_4['30~34세.6'] + df_4['35~39세.6'] + df_4['40~44세.6']\
    + df_4['45~49세.6'] + df_4['50~54세.6'] + df_4['55~59세.6'] + df_4['60~64세.6']
df_4['65세 이상'] = df_4['65~69세.6'] + df_4['65~69세.6'] + df_4['70~74세.6'] + df_4['75~79세.6'] + df_4['80~84세.6']\
    + df_4['85~89세.6'] + df_4['90~94세.6'] + df_4['95~99세.6'] + df_4['100세 이상.6']

# %%
list01 = []
list01.append(df_1['0~14세'].values[0])
list01.append(df_2['0~14세'].values[0])
list01.append(df_3['0~14세'].values[0])
list01.append(df_4['0~14세'].values[0])


list02 = []
list02.append(df_1['15~64세'].values[0])
list02.append(df_2['15~64세'].values[0])
list02.append(df_3['15~64세'].values[0])
list02.append(df_4['15~64세'].values[0])


list03 = []
list03.append(df_1['65세 이상'].values[0])
list03.append(df_2['65세 이상'].values[0])
list03.append(df_3['65세 이상'].values[0])
list03.append(df_4['65세 이상'].values[0])


list03
# Out:
# [5646796, 5674670, 5706422, 5731857]

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 11
matplotlib.rcParams['axes.unicode_minus'] = False
import pandas as pd
import numpy as np

# %%
x = ['1월','2월','3월','4월']
y1 = list01
y2 = list02
y3 = list03

# 그래프 그리기 -> bottom = y1 : y1값 위로 bar를 올린다는 뜻
plt.bar(x,y1,label='0~14세',color='lightgreen')
plt.bar(x,y2,bottom=y1,label='15~64세',color='#666666')
plt.bar(x,y3,bottom=y2,label='65세 이상',color='skyblue')
#---------------------------------------
# y축 그리드 설정
plt.grid(axis='y', alpha=0.3, linestyle='--', linewidth=1)
#------------------------------------------
# y축 범위 설정
plt.ylim(0,30000000)
# 지수 표현방식 없애기
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
#-----------------------------------------
# 범례 표시하기
plt.legend(loc='upper center',ncol=3)
plt.title('2023년 1~4월 전국 연령별 인구현황(남성)',fontdict={'size':14,'weight':600})

# 폰트설정 : fontdict으로 사용
font1 = {'color':'white','weight':550}
font2 = {'weight':550}

for i, txt in enumerate(y1):
    plt.text(x[i],y1[i]-2000000,'{:,.0f}'.format(txt),ha='center',fontdict=font2)
for i, txt in enumerate(y2):
    plt.text(x[i],y1[i]+y2[i]-10000000,'{:,.0f}'.format(txt),ha='center',fontdict=font1)
for i, txt in enumerate(y3):
    plt.text(x[i],y1[i]+y2[i]+y3[i]-6000000,'{:,.0f}'.format(txt),ha='center',fontdict=font2)


plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_21768\3950685037.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
