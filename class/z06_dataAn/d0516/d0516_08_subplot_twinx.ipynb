# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 11
matplotlib.rcParams['axes.unicode_minus'] = False
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../z20_data/stat_142801.xls',skiprows=2,nrows=2,index_col=0)
df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 출생아 수 to 합계 출산율
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2011    2 non-null      float64
#  1   2012    2 non-null      float64
#  2   2013    2 non-null      float64
#  3   2014    2 non-null      float64
#  4   2015    2 non-null      float64
#  5   2016    2 non-null      float64
#  6   2017    2 non-null      float64
#  7   2018    2 non-null      float64
#  8   2019    2 non-null      float64
#  9   2020    2 non-null      float64
# dtypes: float64(10)
# memory usage: 176.0+ bytes

# %%
# df.rename(index={'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출산율'},inplace=True)
# df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2011  471.3   1.244
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840

# %%
df.columns
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df['출생아 수']
# Out:
# 2011    471.3
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.bar(df.index,df['출생아 수'],color='#FF812D')
# y축 라벨 및 범위 지정
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(200,700)
ax1.set_yticks([300,400,500,600])
for i, txt in enumerate(df['출생아 수']):
    ax1.text(df.index[i],df['출생아 수'][i]+10,txt,ha='center')


ax2 = ax1.twinx()   # ax1과 x축을 같이 쓴다
ax2.plot(df.index,df['합계 출산율'],color='#FFD100',marker='o',ms=8,mfc='#FFD100',lw=3,mec='white')
# y축 라벨 및 범위 지정
ax2.set_ylabel('합계 출산율(가임여성 1명당 명)')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
for i, txt in enumerate(df['합계 출산율']):
    ax2.text(df.index[i],df['합계 출산율'][i]+0.06,txt,ha='center')
    
plt.show()
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27048\3122188177.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax1.text(df.index[i],df['출생아 수'][i]+10,txt,ha='center')
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27048\3122188177.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax2.text(df.index[i],df['합계 출산율'][i]+0.06,txt,ha='center')

# %%
# subplot 그리기
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.bar(df.index, df['출생아 수'], color='#ff812d')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.set_ylabel('출생아 수 (천 명)')
for i, txt in enumerate(df['출생아 수']):
    ax1.text(df.index[i], df['출생아 수'][i]+10, txt, ha='center')

ax2 = ax1.twinx()  # ax1과 같은 x축을 사용할거야~
ax2.plot(df.index, df['합계 출산율'], color='#ffd100',marker='*',ms=8,lw=3,mec='blue',mfc='blue')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출산율(가임여성 1명당 명)')
for i, txt in enumerate(df['합계 출산율']):
    ax2.text(df.index[i], df['합계 출산율'][i]+0.06, txt, ha='center')
# Out:
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27048\3851467413.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax1.text(df.index[i], df['출생아 수'][i]+10, txt, ha='center')
# C:\Users\KOREAVC\AppData\Local\Temp\ipykernel_27048\3851467413.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax2.text(df.index[i], df['합계 출산율'][i]+0.06, txt, ha='center')
