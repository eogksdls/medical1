# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 11
matplotlib.rcParams['axes.unicode_minus'] = False
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../z20_data/score.xlsx',index_col='지원번호')
df.head(3)
# Out:
#        이름   학교  학년    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# 1번    강나래  구로고   3  197  90  85  100  95  84      Python
# 2번    강태원  구로고   3  194  50  63   88  49  58        Java
# 3번    강호림  구로고   2  168  60  77   56  88  93  Javascript

# %%
plt.bar(df['이름'],df['국어'])
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(df['이름'],df['영어'],label='영어')
plt.plot(df['이름'],df['수학'],label='수학')
plt.legend(loc=1,ncol=2)

# %%
# 산점도 그래프
plt.scatter(df['영어'],df['수학'])   # 영어점수와 수학점수의 분포도를 알 수 있음
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
# 학년별로 점수 크기를 비교하고 싶어
df['학년']
# Out:
# 지원번호
# 1번    3
# 2번    3
# 3번    2
# 4번    1
# 5번    1
# 6번    3
# 7번    2
# 8번    2
# Name: 학년, dtype: int64

# %%
plt.scatter(df['영어'],df['수학'],label='수학')
plt.scatter(df['영어'],df['과학'],label='과학')
plt.legend(loc='upper center',ncol=2)
plt.xlabel('영어점수')
# Out:
# Text(0.5, 0, '영어점수')

# %%
np.random.rand(8)*1000
# Out:
# array([430.39472409, 649.27365257, 350.25294412, 566.75660914,
#          1.34727154, 257.74941498, 341.89484763, 877.31391983])

# %%
sizes = np.random.rand(8)*1000
# s는 산점도 그래프 점의 크기를 조절
# s=sizes, sizes를 랜덤으로 생성함
plt.scatter(df['영어'],df['수학'],s=sizes)

# %%
# 학년별로 크기를 조절
# 1학년 : 1*500, 2학년 : 2*500, 3학년 : 3*500
sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s=sizes)
plt.xlabel('영어점수')
plt.ylabel('수학점수')
# Out:
# Text(0, 0.5, '수학점수')

# %%
# 학년별로 크기, 색상 조절
# 1학년 : 1*500, 2학년 : 2*500, 3학년 : 3*500
# 학년에 따라 색상을 넣어달라
sizes = df['학년']*500
plt.scatter(df['영어'],df['수학'],s=sizes,c=df['학년'],cmap='viridis')
plt.xlabel('영어점수')
plt.ylabel('수학점수')

# 컬러 bar의 눈금표시 : ticks, 라벨표시 : label, 컬러bar 크기조절 : shrink
# 컬러바 위치 하단배치 : orientation='horizontal'
plt.colorbar(ticks=[1,2,3],label='학년',shrink=0.3,orientation='horizontal')

# %%
# stu_score1 50명만 산점도 그래프 출력
# x축 이름은 90도로 돌려서 출력
df = pd.read_csv('../z20_data/stu_score1.csv',index_col='no')
df = df.head(50)
df
# Out:
#            id  kor  eng  math  total        avg  rank      c_date
# no
# 1     Joelynn   55   87    68    210  70.000000     0  2024-04-04
# 2      Bambie   73   69    77    219  73.000000     0  2024-04-01
# 3        Orin   92   97    90    279  93.000000     0  2024-04-04
# 4        Puff   98   60    78    236  78.666667     0  2024-04-04
# 5     Godfree   66   72    59    197  65.666667     0  2024-04-06
# 6       Penny   64   66    63    193  64.333333     0  2024-04-08
# 7       Matti   84   81    97    262  87.333333     0  2024-04-02
# 8    Catherin   58   69    95    222  74.000000     0  2024-04-02
# 9       Flora   95   58    72    225  75.000000     0  2024-04-03
# 10     Rhodia   60   97    72    229  76.333333     0  2024-04-09
# 11    Atlante   63   99    87    249  83.000000     0  2024-04-09
# 12  Zacharias   80   59    72    211  70.333333     0  2024-04-01
# 13      Teddi   74   91    76    241  80.333333     0  2024-04-03
# ...

# %%
plt.figure(figsize=(13,5))
plt.scatter(df['id'],df['total'])
# plt.scatter(df['id'],df['eng'])
# plt.scatter(df['id'],df['math'])

plt.title('성적 분포도',fontdict={'size':13,'weight':600})
plt.xlabel('학생id',fontdict={'weight':600})
plt.ylabel('total',fontdict={'weight':600})
plt.xticks(rotation=90)
plt.show()
